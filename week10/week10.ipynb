# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtaviousA1/The-python-Assignments/blob/main/week10/week10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: roster.py
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
#add items to list
#remove items from list
#Edit item on the list
# PROGRAM LOGIC
#While True loop
#see the list
#call see the list fuction
#add the player to the list
#call the add item fuction
#ask user which player to quit
#edit item function
