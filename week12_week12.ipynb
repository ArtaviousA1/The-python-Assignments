# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtaviousA1/The-python-Assignments/blob/main/week12_week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rectangle.py
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
# Function: calculate_rectangle(length, width)
# - Take in length and width as parameters
# - Calculate area = length * width
# - Calculate perimeter = 2 * (length + width)
# - Pack both values into a tuple like (area, perimeter)
# - Return the tuple

# PROGRAM LOGIC
# - Ask user for length
# - Ask user for width
# - Call the function with user inputs
# - Unpack returned tuple into my_area and my_perimeter
# - Print the results clearly
