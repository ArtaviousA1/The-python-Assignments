# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtaviousA1/The-python-Assignments/blob/main/Week%203/Week%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Assign values to name, goal, birth_year, and current_year.

#Calculate age.

#Print the top border line using string multiplication.

#Print the bio sentences.

#Print the bottom border line using string multiplication.
