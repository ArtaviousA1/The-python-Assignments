# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtaviousA1/The-python-Assignments/blob/main/Week%203/Week_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = 'Artavious'
goal = 'become a software developer'
birth_year = 2003
current_year =2026
age = current_year - birth_year

border_length = 47

print("-" * border_length)
print(f"My name is Artavious and I am 22 years old.")
print(f"My goal is to become a software developer.")
print("-" * border_length)
# Out:
# -----------------------------------------------
# My name is Artavious and I am 22 years old.
# My goal is to become a software developer.
# -----------------------------------------------
