# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtaviousA1/The-python-Assignments/blob/main/week14/week14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: library.py
# IMPORT STATEMENTS

# CLASS DEFINITIONS
class Book:
    # __init__(self, title, author)
    # - store title
    # - store author
    # - set is_available to True by default

    # __str__(self)
    # - if is_available is True → "Available"
    # - else → "Checked Out"
    # - return formatted string with title, author, status

    # checkout(self)
    # - set is_available to False using self

    # return_book(self)
    # - set is_available to True using self


# PROGRAM LOGIC
# - create book objects
# - print their status
# - checkout one book
# - print updated status
