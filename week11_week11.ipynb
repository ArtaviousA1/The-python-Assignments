# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtaviousA1/The-python-Assignments/blob/main/week11_week11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: gradebook.py
# IMPORT STATEMENTS
# while loop to collect student names
# stop when user types "done"
# store name and grade in dictionary
# calculate average using sum of values
# FUNCTION DEFINITIONS
# PROGRAM LOGIC
