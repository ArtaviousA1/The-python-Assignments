# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtaviousA1/The-python-Assignments/blob/main/week%2013/week13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: journal.py
# IMPORT STATEMENTS
# (none needed for this program)

# FUNCTION DEFINITIONS

def write_entry(filename, entry):
    # open file in append mode
    # write entry to file with newline (\n)
    # close file
    pass


def read_journal(filename):
    # open file in read mode
    # read contents
    # print contents
    # handle error if file doesn't exist
    pass


# PROGRAM LOGIC

# set filename (journal.txt)

# start while loop
    # ask user: (W)rite, (R)ead, or (Q)uit

    # if W:
        # ask for entry
        # call write_entry
        # print confirmation

    # if R:
        # call read_journal

    # if Q:
        # break loop

    # else:
        # print invalid message

def write_entry(filename, entry):
    file = open(filename, 'a')
    file.write(entry + '\n')  # ensures new line
    file.close()


filename = "journal.txt"

while True:
    choice = input("(W)rite, (R)ead, or (Q)uit? ").lower()

    if choice == 'w':
        entry = input("Enter your entry: ")
        write_entry(filename, entry)
        print("Entry saved.")

    elif choice == 'r':
        print("Read feature coming soon!")  # placeholder

    elif choice == 'q':
        print("Goodbye!")
        break

    else:
        print("Invalid choice.")

def write_entry(filename, entry):
    file = open(filename, 'a')
    file.write(entry + '\n')
    file.close()


def read_journal(filename):
    try:
        file = open(filename, 'r')
        contents = file.read()
        print("\n--- Your Journal ---")
        print(contents)
        file.close()
    except FileNotFoundError:
        print("No journal entries found yet.")


filename = "journal.txt"

while True:
    choice = input("(W)rite, (R)ead, or (Q)uit? ").lower()

    if choice == 'w':
        entry = input("Enter your entry: ")
        write_entry(filename, entry)
        print("Entry saved.")

    elif choice == 'r':
        read_journal(filename)

    elif choice == 'q':
        print("Goodbye!")
        break

    else:
        print("Invalid choice.")
# Out:
# (W)rite, (R)ead, or (Q)uit? w
# Enter your entry: Today I learned about file persistence in Python!
# Entry saved.
# (W)rite, (R)ead, or (Q)uit? r
# Read feature coming soon!
# (W)rite, (R)ead, or (Q)uit? q
# Goodbye!
# (W)rite, (R)ead, or (Q)uit? R
#
# --- Your Journal ---
# Today I learned about file persistence in Python!
# Today I learned about file persistence in Python!
