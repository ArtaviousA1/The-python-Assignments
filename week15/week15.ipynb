# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtaviousA1/The-python-Assignments/blob/main/week15/week15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import os
from datetime import datetime

TASKS_FILE = "tasks.json"
HISTORY_FILE = "history.json"

def load_data(file):
    if not os.path.exists(file):
        return []
    with open(file, "r") as f:
        return json.load(f)

def save_data(file, data):
    with open(file, "w") as f:
        json.dump(data, f, indent=4)

def add_task():
    name = input("Enter task name: ")
    priority = input("Enter priority (1=High, 2=Medium, 3=Low): ")

    if priority not in ["1", "2", "3"]:
        print("Invalid priority.")
        return

    tasks = load_data(TASKS_FILE)
    tasks.append({
        "name": name,
        "priority": int(priority),
        "created_at": datetime.now().isoformat()
    })
    save_data(TASKS_FILE, tasks)
    print("Task added.")

def view_tasks():
    tasks = load_data(TASKS_FILE)
    if not tasks:
        print("No tasks found.")
        return

    for i, task in enumerate(tasks):
        print(f"{i+1}. {task['name']} (Priority {task['priority']})")

def complete_task():
    tasks = load_data(TASKS_FILE)

    if not tasks:
        print("No tasks to complete.")
        return

    view_tasks()
    choice = int(input("Enter task number to complete: ")) - 1

    if choice < 0 or choice >= len(tasks):
        print("Invalid choice.")
        return

    completed = tasks.pop(choice)
    save_data(TASKS_FILE, tasks)

    history = load_data(HISTORY_FILE)
    history.append(completed)
    save_data(HISTORY_FILE, history)

    print("Task completed and saved to history.")

def what_is_next():
    tasks = load_data(TASKS_FILE)

    high_priority = [t for t in tasks if t["priority"] == 1]

    if not high_priority:
        print("You're all caught up! No high priority tasks 👍")
        return

    high_priority.sort(key=lambda x: x["created_at"])
    next_task = high_priority[0]

    print("Next high priority task:")
    print(f"- {next_task['name']}")

def main():
    while True:
        print("\n1. Add Task")
        print("2. View Tasks")
        print("3. Complete Task")
        print("4. What is next?")
        print("5. Exit")

        choice = input("Choose: ")

        if choice == "1":
            add_task()
        elif choice == "2":
            view_tasks()
        elif choice == "3":
            complete_task()
        elif choice == "4":
            what_is_next()
        elif choice == "5":
            break
        else:
            print("Invalid choice.")

if __name__ == "__main__":
    main()
# Out:
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. What is next?
# 5. Exit
# Choose: Add Task
# Invalid choice.
#
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. What is next?
# 5. Exit
# Choose: view tasks
# Invalid choice.
#
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. What is next?
# 5. Exit
# Choose: complete
# Invalid choice.
#
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. What is next?
# 5. Exit
# Choose: what is next?
# Invalid choice.
#
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. What is next?
# 5. Exit
# Choose: exit
# Invalid choice.
#
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. What is next?
# 5. Exit
